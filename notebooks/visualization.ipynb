# %% [markdown]
# # Phantom Neighbors - Paper Figures and Tables
#
# This notebook generates all figures and tables from the paper.
# Run the experiment scripts first (see `scripts/run_all.sh`).

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load results
# results = np.load('results/rq2/mimic_results.npz', allow_pickle=True)
